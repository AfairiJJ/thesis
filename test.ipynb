# %%
import joblib
import torch
import pandas

# %%
torch.load('./config/gen_test')
# Out:
# OrderedDict([('hidden_layers.0.weight',
#               tensor([[ 0.0196,  0.0092,  0.0805,  ..., -0.0809, -0.0051, -0.0042],
#                       [-0.0019, -0.0716,  0.0076,  ..., -0.0164, -0.0090, -0.0627],
#                       [-0.0607, -0.0341, -0.0379,  ...,  0.0417, -0.0150,  0.0765],
#                       ...,
#                       [ 0.0795,  0.0079,  0.0540,  ..., -0.0272,  0.0334,  0.0646],
#                       [-0.0722, -0.0118, -0.0083,  ...,  0.0775, -0.0816,  0.0585],
#                       [-0.0148,  0.0519, -0.0851,  ..., -0.0170, -0.0034, -0.0795]])),
#              ('hidden_layers.0.bias',
#               tensor([ 0.0647,  0.0651,  0.0767,  0.0783,  0.0060,  0.0887,  0.0590,  0.0888,
#                       -0.0946,  0.0305, -0.0600, -0.0652,  0.0238, -0.0241, -0.0293,  0.0970,
#                        0.0908, -0.0843, -0.0271, -0.0972, -0.0919,  0.0990, -0.0156, -0.0585,
# ...
